# %%
# %pip install psycopg2
# Out:
# Collecting psycopg2Note: you may need to restart the kernel to use updated packages.
#
#   Downloading psycopg2-2.9.12-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# Downloading psycopg2-2.9.12-cp312-cp312-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 1.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.8/2.8 MB 1.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.8/2.8 MB 1.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.8/2.8 MB 1.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.8/2.8 MB 1.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.8/2.8 MB 1.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.8/2.8 MB 1.9 MB/s eta 0:00:02
#    ------------------------------ --------- 2.1/2.8 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 1.3 MB/s  0:00:02
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.12
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine

# Samakan dengan config yang Alifia pakai di FastAPI
DB_USER = "postgres"
DB_PASSWORD = "mabaPENS24"
DB_HOST = "10.207.210.18"
DB_PORT = "5432"
DB_NAME = "superstore_db"

engine = create_engine(
    f"postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)

# Test koneksi
try:
    with engine.connect() as conn:
        print("✅ Koneksi berhasil!")
except Exception as e:
    print(f"❌ Gagal konek: {e}")
# Out:
# ✅ Koneksi berhasil!

# %% [markdown]
# ## load data langsung dari db ke pandas

# %%
# Tabel utama untuk modeling
df_orders   = pd.read_sql("SELECT * FROM orders", engine)
df_products = pd.read_sql("SELECT * FROM products", engine)
df_customers = pd.read_sql("SELECT * FROM customers", engine)
df_locations = pd.read_sql("SELECT * FROM locations", engine)

print("Orders:", df_orders.shape)
print("Products:", df_products.shape)
df_orders.head()
# Out:
# Orders: (9994, 10)
# Products: (1850, 4)
#    order_item_id        order_id  order_date  customer_id  product_id  \
# 0              1  CA-2016-152156  2016-11-02            1           1
# 1              2  CA-2016-152156  2016-11-02            1           2
# 2              3  CA-2016-138688  2016-06-02            2           3
# 3              4  US-2015-108966  2015-10-02            3           4
# 4              5  US-2015-108966  2015-10-02            3           5
#
#    shipment_id  quantity  sales  discount  profit
# 0            1         2  262.0      0.00    42.0
# 1            2         3  732.0      0.00   220.0
# 2            3         2   15.0      0.00     7.0
# 3            4         5  958.0      0.45  -383.0
# 4            5         2   22.0      0.20     3.0

# %%
df_monthly = pd.read_sql("SELECT * FROM ts_sales_monthly", engine)
print(df_monthly.shape)
df_monthly.head()
# Out:
# (782, 11)
#    ts_id  year  month         category sub_category  total_sales  \
# 0      1  2014      1        Furniture    Bookcases       1010.0
# 1      2  2014      1        Furniture       Chairs       4188.0
# 2      3  2014      1        Furniture  Furnishings        712.0
# 3      4  2014      1        Furniture       Tables        333.0
# 4      5  2014      1  Office Supplies   Appliances        313.0
#
#    total_profit  total_quantity  num_orders  avg_discount  \
# 0        -327.0              16           5        0.3000
# 1        1057.0              18           3        0.0000
# 2          91.0              33           9        0.0909
# 3         -17.0               3           1        0.2000
# 4         100.0               8           2        0.1500
#
#                   created_at
# 0 2026-05-13 19:22:52.639371
# 1 2026-05-13 19:22:52.639371
# 2 2026-05-13 19:22:52.639371
# 3 2026-05-13 19:22:52.639371
# 4 2026-05-13 19:22:52.639371
